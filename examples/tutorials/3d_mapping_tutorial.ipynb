# %%
import pygmt

fig = pygmt.Figure()
fig.grdcontour(
    annotation=1000,
    interval=250,
    grid="@earth_relief_15s",
    region=[-92, -90, -1.5, 0.5],
    limit=[-4000, 0],
    projection="M4i",
    frame=True,
)
fig.show()

# %%
# use grdview method
